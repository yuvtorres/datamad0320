# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
from pymongo import MongoClient
dbName = "companies"
mongodbURL = f"mongodb://localhost/{dbName}"
print(mongodbURL)
client = MongoClient(mongodbURL, connectTimeoutMS=2000,serverSelectionTimeoutMS=2000)
db = client.get_database()
# Out:
# mongodb://localhost/companies

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
import re
searchre = re.compile(r"Babelgum")
cur = db.companies.find({"name":searchre})
for c in cur:
    print(c["name"])
# Out:
# Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
from pymongo import ASCENDING, DESCENDING
from pandas.io.json import json_normalize
rest=list(db.companies.find({"number_of_employees":{"$gt":5000}},{"name":1,"number_of_employees":1,'_id':0}).sort([
   ("number_of_employees", DESCENDING)
]).limit(20))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                           name  number_of_employees
# 0                                      Siemens               405000
# 1                                          IBM               388000
# 2                                       Toyota               320000
# 3                                       PayPal               300000
# 4   Nippon Telegraph and Telephone Corporation               227000
# 5                          Samsung Electronics               221726
# 6                                    Accenture               205000
# 7                    Tata Consultancy Services               200300
# 8                    Flextronics International               200000
# 9                                      Safeway               186000
# 10                                        Sony               180500
# 11                                          LG               177000
# 12                                        Ford               171000
# 13                                      Boeing               160000
# 14               Digital Equipment Corporation               140000
# 15                                       Nokia               125000
# 16                         MItsubishi Electric               107000
# 17                         MItsubishi Electric               107000
# 18                                     Comcast               100000
# 19                                 Bertelsmann               100000

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
qsearch={"$and":
         [{"founded_year":{"$gte":2000}},
          {"founded_year":{"$lte":2005}}]
        }
rest=list(db.companies.find(qsearch,  {"name":1,
          "founded_year": 1,
          "_id":0 }).sort([("number_of_employees", DESCENDING)
]))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                               name  founded_year
# 0                        Accenture          2001
# 1                        MetaCarta          2001
# 2                            Avaya          2000
# 3                          Webkinz          2005
# 4     Liberty League International          2001
# ...                            ...           ...
# 3729                Axon Solutions          2004
# 3730                EnterSys Group          2000
# 3731                       Intergy          2003
# 3732                    AfterLogic          2002
# 3733                     EnteGreat          2000
#
# [3734 rows x 2 columns]

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
qsearch={"$and":
         [{"ipo.valuation_amount":{"$gt":100000000}},
          {"founded_year":{"$lt":2010}}]
        }
rest=list(db.companies.find(qsearch,  {"name":1,
          "ipo": 1,
          "_id":0 }).sort([("ipo", DESCENDING)
]))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                     name  ipo.valuation_amount ipo.valuation_currency_code  \
# 0                   GREE          108960000000                         JPY
# 1               Facebook          104000000000                         USD
# 2                 Amazon          100000000000                         USD
# 3                Twitter           18100000000                         USD
# 4                Groupon           12800000000                         USD
# 5                Tencent           11000000000                         USD
# 6        Western Digital            9430000000                         USD
# 7               LinkedIn            9310000000                         USD
# 8           BMC Software            6000000000                         USD
# 9              Rackspace            5440000000                         USD
# 10                 Baidu            4000000000                         USD
# 11           TripAdvisor            3273770000                         USD
# 12              HomeAway            3000000000                         USD
# 13                Zillow            2550000000                         USD
# 14               Nielsen            1600000000                         USD
# 15                  Yelp            1300000000                         USD
# 16                 Chegg            1100000000                         USD
# 17                 Chegg            1100000000                         USD
# 18            Higher One            1060000000                         USD
# 19             OpenTable            1050000000                         USD
# 20         Jive Software            1000000000                         USD
# 21   BrightSource Energy            1000000000                         USD
# 22              QlikTech            1000000000                         USD
# 23      Millennial Media             973500000                         USD
# 24                  Mixi             970000000                         USD
# 25  Cornerstone OnDemand             900000000                         USD
# 26              Infoblox             824000000                         USD
# 27            SolarWinds             803000000                         USD
# 28                   Wix             750000000                         USD
# 29               Marketo             465000000                         USD
# 30               Opsware             450000000                         USD
# 31            Shutterfly             350000000                         USD
# 32               Telenav             337000000                         USD
# 33        Rally Software             315000000                         USD
# 34            Brightcove             290000000                         USD
# 35        ChannelAdvisor             287000000                         USD
# 36             DemandTec             245000000                         USD
# 37           KIT digital             235000000                         USD
# 38                 Tudou             174000000                         USD
# 39            QuinStreet             140000000                         USD
# 40               Geeknet             134000000                         USD
# 41            Salesforce             110000000                         USD
#
#     ipo.pub_year  ipo.pub_month  ipo.pub_day ipo.stock_symbol
# 0         2008.0           12.0         17.0             3632
# 1         2012.0            5.0         18.0        NASDAQ:FB
# 2         1997.0            5.0          NaN      NASDAQ:AMZN
# 3         2013.0           11.0          7.0        NYSE:TWTR
# 4         2011.0           11.0          7.0      NASDAQ:GRPN
# 5         2004.0            6.0         16.0          HK:0700
# 6            NaN            NaN          NaN         NYSE:WDC
# 7         2011.0            7.0         20.0        NYSE:LNKD
# 8         1988.0            8.0         12.0       NASDAQ:BMC
# 9         2011.0           11.0          7.0              RAX
# 10        2005.0            8.0          5.0      NASDAQ:BIDU
# 11        2011.0           12.0         21.0             TRIP
# 12        2011.0            6.0         29.0      NASDAQ:AWAY
# 13        2011.0            7.0         19.0         NASDAQ:Z
# 14        2011.0            1.0         26.0        NYSE:NLSN
# 15        2012.0            3.0          2.0        NYSE:YELP
# 16        2013.0           11.0         14.0        NYSE:CHGG
# 17        2013.0           11.0         14.0        NYSE:CHGG
# 18           NaN            NaN          NaN         NYSE:ONE
# 19        2009.0            5.0         21.0      NASDAQ:OPEN
# 20        2012.0            2.0          3.0      NASDAQ:JIVE
# 21        2011.0            4.0         22.0      NASDAQ:BRSE
# 22        2010.0            7.0         16.0             QLIK
# 23        2012.0            3.0         28.0          NYSE:MM
# 24        2006.0            9.0         14.0          JP:2121
# 25        2011.0            7.0          5.0             CSOD
# 26        2012.0            4.0         20.0        NYSE:BLOX
# 27        2009.0            5.0         20.0              SWI
# 28        2013.0           11.0          6.0       NASDAQ:WIX
# 29        2013.0            4.0          2.0      NASDAQ:MKTO
# 30        2001.0            3.0          9.0      NASDAQ:LDCL
# 31        2006.0            9.0         29.0             SFLY
# 32        2010.0            5.0         13.0             TNAV
# 33        2013.0            4.0         12.0             RALY
# 34        2012.0            2.0         17.0      NASDAQ:BCOV
# 35        2013.0            5.0         23.0        NYSE:ECOM
# 36        2011.0            2.0         14.0      NASDAQ:DMAN
# 37        2010.0            7.0         27.0             KITD
# 38           NaN            NaN          NaN      NASDAQ:TUDO
# 39        2010.0            1.0         11.0      NASDAQ:QNST
# 40        2010.0           11.0          2.0             GKNT
# 41        2004.0            7.0          2.0         NYSE:CRM

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
qsearch={"$and":
         [{"founded_year":{"$lt":2005}},
          {"number_of_employees":{"$lt":1000}}]
        }
rest=list(db.companies.find(qsearch,  {"name":1,
          "number_of_employees": 1,
          "_id":0 }).sort([("number_of_employees", DESCENDING)
]).limit(10))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                               name  number_of_employees
# 0             Infinera Corporation                  974
# 1  NorthPoint Communications Group                  948
# 2                     888 Holdings                  931
# 3               Forrester Research                  903
# 4                        SonicWALL                  900
# 5                       Webmetrics                  900
# 6             Cornerstone OnDemand                  881
# 7                             Yelp                  800
# 8                          MySpace                  800
# 9                         ZoomInfo                  800

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
qsearch={"partners": { "$exists" : False } }
rest=list(db.companies.find(qsearch,  {"name":1,
                    "_id":0 })
         )
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
qsearch={"category_code": { "$eq" : None } }
rest=list(db.companies.find(qsearch,  {"name":1,
                    "_id":0 })
         )
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#               name
# 0       Collective
# 1          Snimmer
# 2           KoolIM
# 3     Level9 Media
# 4          VidKing
# ...            ...
# 2746        Nellix
# 2747      Cantimer
# 2748  cruisecritic
# 2749      Geekdive
# 2750      Coloroot
#
# [2751 rows x 1 columns]

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
qsearch={"$and":
         [{"number_of_employees":{"$gte":100}},
          {"number_of_employees":{"$lt":1000}}]
        }
rest=list(db.companies.find(qsearch,  {"name":1,
          "number_of_employees": 1,
          "_id":0 }).sort([("number_of_employees", DESCENDING)
]))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                                 name  number_of_employees
# 0                        Datamonitor                  984
# 1               Infinera Corporation                  974
# 2                                Box                  950
# 3    NorthPoint Communications Group                  948
# 4                       888 Holdings                  931
# ..                               ...                  ...
# 912                      ZoomSystems                  100
# 913                            Exent                  100
# 914                         Mashable                  100
# 915       Applied Language Solutions                  100
# 916                         NextLabs                  100
#
# [917 rows x 2 columns]

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
qsearch={"ipo.valuation_amount": { "$ne" : None } }
rest=list(db.companies.find(qsearch,  {"name":1,
          "ipo": 1,
          "_id":0 }).sort([("ipo", DESCENDING)
]))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                           name  ipo.valuation_amount  \
# 0                         GREE          108960000000
# 1                     Facebook          104000000000
# 2                       Amazon          100000000000
# 3                      Twitter           18100000000
# 4                      Groupon           12800000000
# ..                         ...                   ...
# 56  Energy and Power Solutions              25000000
# 57                      Vringo              11003200
# 58                    GT Solar               5000000
# 59                        DeNA                117900
# 60                        DeNA                117900
#
#    ipo.valuation_currency_code  ipo.pub_year  ipo.pub_month  ipo.pub_day  \
# 0                          JPY        2008.0           12.0         17.0
# 1                          USD        2012.0            5.0         18.0
# 2                          USD        1997.0            5.0          NaN
# 3                          USD        2013.0           11.0          7.0
# 4                          USD        2011.0           11.0          7.0
# ..                         ...           ...            ...          ...
# 56                         USD        2010.0            3.0         31.0
# 57                         USD        2010.0            6.0         22.0
# 58                         USD        2008.0            7.0         23.0
# 59                         JPY        2005.0            2.0         25.0
# 60                         JPY        2005.0            2.0         25.0
#
#    ipo.stock_symbol
# 0              3632
# 1         NASDAQ:FB
# 2       NASDAQ:AMZN
# 3         NYSE:TWTR
# 4       NASDAQ:GRPN
# ..              ...
# 56              EPS
# 57             VRNG
# 58             SOLR
# 59         TYO:2432
# 60         TYO:2432
#
# [61 rows x 7 columns]

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
qsearch={}
rest=list(db.companies.find(qsearch,  {"name":1,
          "number_of_employees": 1,
          "_id":0 }).sort([("number_of_employees", DESCENDING)
]).limit(10))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                          name  number_of_employees
# 0                                     Siemens               405000
# 1                                         IBM               388000
# 2                                      Toyota               320000
# 3                                      PayPal               300000
# 4  Nippon Telegraph and Telephone Corporation               227000
# 5                         Samsung Electronics               221726
# 6                                   Accenture               205000
# 7                   Tata Consultancy Services               200300
# 8                   Flextronics International               200000
# 9                                     Safeway               186000

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
qsearch={"founded_month":{"$gt":6}}
rest=list(db.companies.find(qsearch, {"name":1,
          "_id":0 }).limit(1000))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#              name
# 0        Wetpaint
# 1            Zoho
# 2       Omnidrive
# 3            Digg
# 4           Joost
# ..            ...
# 995   SavvyAuntie
# 996  AccountMaven
# 997      Chapatiz
# 998       YOOWALK
# 999   Data Domain
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
qsearch={"$and":
         [{"founded_year":{"$lt":2000}},
          {"acquisition.price_amount":{"$gt":10000}}]
        }
rest=list(db.companies.find(qsearch,  {"name":1,
          "acquisition.price_amount": 1,
          "_id":0 }))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                name  acquisition.price_amount
# 0                           Postini                 625000000
# 1                          SideStep                 180000000
# 2                        Recipezaar                  25000000
# 3                           Cyworld                   7140000
# 4                            PayPal                1500000000
# ..                              ...                       ...
# 220                         Savvion                  49000000
# 221            Inventa Technologies                  30000000
# 222             Universal Microwave                  23200000
# 223     Advanced Control Components                  18780000
# 224  Contemporary Computer Services                  15040000
#
# [225 rows x 2 columns]

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
qsearch={"acquisition.acquired_year":{"$gt":2010} }

rest=list(db.companies.find(qsearch,  {"name":1,
          "acquisition": 1,
          "_id":0 }).sort("acquisition.price_amount", DESCENDING))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                         name  acquisition.price_amount  \
# 0                   T-Mobile              3.900000e+10
# 1       Goodrich Corporation              1.840000e+10
# 2                        LSI              6.600000e+09
# 3     National Semiconductor              6.500000e+09
# 4                      Ariba              4.300000e+09
# ..                       ...                       ...
# 731                 MediaPal                       NaN
# 732                   Vertro                       NaN
# 733                     ALOT                       NaN
# 734                MyChances                       NaN
# 735  Celestial Semiconductor                       NaN
#
#     acquisition.price_currency_code acquisition.term_code  \
# 0                               USD                  None
# 1                               USD                  None
# 2                               USD                  cash
# 3                               USD                  cash
# 4                               USD                  None
# ..                              ...                   ...
# 731                             USD                  None
# 732                             USD                 stock
# 733                             USD                 stock
# 734                             USD                  None
# 735                             USD                  None
#
#                                 acquisition.source_url  \
# 0    http://techcrunch.com/2011/03/20/in-the-race-f...
# 1    http://www.masshightech.com/stories/2011/09/19...
# 2    http://dealbook.nytimes.com/2013/12/16/avago-t...
# 3    http://www.national.com/news/item/0,1735,1522,...
# 4    http://techcrunch.com/2012/05/22/sap-to-acquir...
# ..                                                 ...
# 731  http://www.freshnews.com/news/525524/voxpop-wo...
# 732  http://techcrunch.com/2011/10/17/digital-media...
# 733  http://techcrunch.com/2011/10/17/digital-media...
# 734  http://www.parchment.com/press-releases/new-st...
# 735  http://www.freshnews.com/news/444859/cavium-ne...
#
#                         acquisition.source_description  \
# 0    In The Race For More Spectrum, AT&T Is Acquiri...
# 1            UTC shells out $18.4 billion for Goodrich
# 2                    Avago to Buy LSI for $6.6 Billion
# 3    TI to acquire National Semiconductor Complemen...
# 4                SAP To Acquire Ariba For $4.3 Billion
# ..                                                 ...
# 731  VoxPop Worldwide Acquires Global Rights to eco...
# 732  Digital Media Companies Inuvo And Vertro To Merge
# 733  Digital Media Companies Inuvo And Vertro To Merge
# 734  New Student-Developed Site Helps College Hopef...
# 735  CAVIUM NETWORKS SIGNS DEFINITIVE AGREEMENT TO ...
#
#      acquisition.acquired_year  acquisition.acquired_month  \
# 0                         2011                         3.0
# 1                         2011                         9.0
# 2                         2013                        12.0
# 3                         2011                         4.0
# 4                         2012                         5.0
# ..                         ...                         ...
# 731                       2011                         7.0
# 732                       2012                         3.0
# 733                       2012                         3.0
# 734                       2011                         4.0
# 735                       2011                         1.0
#
#      acquisition.acquired_day acquisition.acquiring_company.name  \
# 0                        20.0                               AT&T
# 1                        22.0                United Technologies
# 2                        16.0                 Avago Technologies
# 3                         4.0                  Texas Instruments
# 4                        22.0                                SAP
# ..                        ...                                ...
# 731                      25.0                   VoxPop Worldwide
# 732                       1.0                              Inuvo
# 733                       1.0                              Inuvo
# 734                       NaN                          Parchment
# 735                      31.0                             Cavium
#
#     acquisition.acquiring_company.permalink
# 0                                      at-t
# 1                       united-technologies
# 2                        avago-technologies
# 3                         texas-instruments
# 4                                       sap
# ..                                      ...
# 731                        voxpop-worldwide
# 732                                   inuvo
# 733                                   inuvo
# 734                               parchment
# 735                         cavium-networks
#
# [736 rows x 11 columns]

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
qsearch={"founded_year":{"$ne":None}} # he limitado sino me salia error

rest=list(db.companies.find(qsearch,  {"name":1,
          "founded_year": 1,
          "_id":0 }).sort("founded_year", ASCENDING).limit(10))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                   name  founded_year
# 0           Alstrasoft          1800
# 1          SmallWorlds          1800
# 2              US Army          1800
# 3               DuPont          1802
# 4             McKesson          1833
# 5  Bachmann Industries          1833
# 6          Bertelsmann          1835
# 7              Accuity          1836
# 8               CENTRA          1839
# 9               WeGame          1840

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
qsearch={"founded_day":{"$lte":7}} 

rest=list(db.companies.find(qsearch,  {"name":1,
          "founded_year": 1,
          "founded_day": 1,
          "acquisition.price_amount" : 1,
          "_id":0 }).sort("acquisition.price_amount", DESCENDING).limit(10))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                 name  founded_year  founded_day  acquisition.price_amount
# 0           Netscape          1994            4                4200000000
# 1             PayPal          1998            1                1500000000
# 2             Zappos          1999            1                1200000000
# 3            Alibaba          1999            1                1000000000
# 4            Postini          1999            2                 625000000
# 5             Danger          1999            1                 500000000
# 6  Clearwell Systems          2004            6                 410000000
# 7         PrimeSense          2005            1                 345000000
# 8             Amobee          2005            1                 321000000
# 9        BlueLithium          2004            1                 300000000

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
qsearch={ "$and" : [ { "category_code" : { "$eq" : "web" }} ,
                    { "number_of_employees": {"$gt" : 4000 }}
                   ]}

rest=list(db.companies.find(qsearch,  {"name":1,
          "founded_year": 1,
          "number_of_employees" : 1,
          "_id":0 }).sort("number_of_employees", ASCENDING).limit(10))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                             name  number_of_employees  founded_year
# 0                        Expedia                 4400          1996
# 1                            AOL                 8000          1985
# 2                        Webkinz                 8657          2005
# 3                        Rakuten                10000          1997
# 4  Los Angeles Times Media Group                10000          1881
# 5                        Groupon                10000          2008
# 6                         Yahoo!                13600          1994
# 7                           eBay                15000          1995
# 8                       Experian                15500          1980

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
qsearch={ "$and" : [ { "acquisition.price_amount" : { "$gt" : 10000000 }} ,
                    { "acquisition.price_currency_code": {"$eq" : "EUR" }}
                   ]}

rest=list(db.companies.find(qsearch,  {"name":1,
          "acquisition.price_amount": 1,
          "acquisition.price_currency_code" : 1,
          "_id":0 }).limit(10))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                   name  acquisition.price_amount  \
# 0                  ZYB                  31500000
# 1              Apertio                 140000000
# 2    Greenfield Online                  40000000
# 3              Webedia                  70000000
# 4            Wayfinder                  24000000
# 5  Tuenti Technologies                  70000000
# 6       BioMed Central                  43400000
#
#   acquisition.price_currency_code
# 0                             EUR
# 1                             EUR
# 2                             EUR
# 3                             EUR
# 4                             EUR
# 5                             EUR
# 6                             EUR

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
qsearch={ "acquisition.acquired_month" : { "$lt" : 4 }}
                    
rest=list(db.companies.find(qsearch,  {"name":1,
          "acquisition": 1 ,
          "_id":0 }).limit(10))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#           name  acquisition.price_amount acquisition.price_currency_code  \
# 0         Kyte                       NaN                             USD
# 1   NetRatings               327000000.0                             USD
# 2       blogTV                       NaN                             USD
# 3   Livestream                       NaN                             USD
# 4     iContact               169000000.0                             USD
# 5      Coghead                       NaN                             USD
# 6  Dailymotion               168000000.0                             USD
# 7     Netvibes                       NaN                             USD
# 8   BabyCenter                       NaN                             USD
# 9       Flickr                       NaN                             USD
#
#   acquisition.term_code                             acquisition.source_url  \
# 0                  None  http://techcrunch.com/2011/01/31/exclusive-kit...
# 1                  cash  http://login.vnuemedia.com/hr/login/login_subs...
# 2                  None  http://techcrunch.com/2013/03/13/younow-buys-b...
# 3        cash_and_stock
# 4        cash_and_stock  http://techcrunch.com/2012/02/28/vocus-buys-em...
# 5                  None  http://www.techcrunch.com/2009/02/19/sap-acqui...
# 6                  None  http://techcrunch.com/2013/02/22/orange-acquir...
# 7                  None  http://www.marketwatch.com/story/dassault-syst...
# 8                  None  http://www.investor.jnj.com/releasedetail.cfm?...
# 9        cash_and_stock  http://news.cnet.com/Yahoo-buys-photo-sharing-...
#
#                       acquisition.source_description  \
# 0  KIT digital Acquires KickApps, Kewego AND Kyte...
# 1                    Nielsen buys rest of NetRatings
# 2  Live Social Video Network YouNow Acquires Stre...
# 3                                            company
# 4  Vocus Buys Email Marketing Company iContact Fo...
# 5  SAP Acquires Cogheadâ€™s Technology As It Look...
# 6  Orange Acquired Dailymotion For $168 Million B...
# 7                Dassault Systemes Acquires Netvibes
# 8  Johnson & Johnson Acquires BabyCenter From eTo...
# 9                                               CNET
#
#    acquisition.acquired_year  acquisition.acquired_month  \
# 0                       2011                           1
# 1                       2007                           2
# 2                       2013                           3
# 3                       2008                           1
# 4                       2012                           2
# 5                       2009                           2
# 6                       2013                           2
# 7                       2012                           2
# 8                       2001                           3
# 9                       2005                           3
#
#    acquisition.acquired_day acquisition.acquiring_company.name  \
# 0                      31.0                        KIT digital
# 1                       NaN                            Nielsen
# 2                      13.0                             YouNow
# 3                       1.0                             Adviqo
# 4                      28.0                              Vocus
# 5                      19.0                                SAP
# 6                      22.0                             Orange
# 7                       9.0                  Dassault Systemes
# 8                       2.0                  Johnson & Johnson
# 9                       NaN                             Yahoo!
#
#   acquisition.acquiring_company.permalink
# 0                             kit-digital
# 1                                 nielsen
# 2                                  younow
# 3                                  adviqo
# 4                                   vocus
# 5                                     sap
# 6                                  orange
# 7                                dassault
# 8                         johnson-johnson
# 9                                   yahoo

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
qsearch={"$and":
         [{"founded_year":{"$gte":2000}},
          {"founded_year":{"$lte":2010}},
          {"acquisition.acquired_year":{"$gte":2011}}]}
                    
rest=list(db.companies.find(qsearch,  {"name":1,
                                       "founded_year" :1,
                                       "acquisition": 1 ,
                                       "_id":0 }).limit(10))
json_normalize(rest)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # Remove the CWD from sys.path while we load stuff.
#               name  founded_year  acquisition.price_amount  \
# 0         Wetpaint          2005                30000000.0
# 1             Geni          2006                       NaN
# 2             Digg          2004                  500000.0
# 3             Kyte          2006                       NaN
# 4  Jingle Networks          2005                62500000.0
# 5           blogTV          2006                       NaN
# 6        delicious          2003                       NaN
# 7        Revision3          2005                30000000.0
# 8         iContact          2003               169000000.0
# 9          Mashery          2006                       NaN
#
#   acquisition.price_currency_code acquisition.term_code  \
# 0                             USD        cash_and_stock
# 1                             USD                  None
# 2                             USD                  None
# 3                             USD                  None
# 4                             USD        cash_and_stock
# 5                             USD                  None
# 6                             USD                  None
# 7                             USD                  None
# 8                             USD        cash_and_stock
# 9                             USD                  None
#
#                               acquisition.source_url  \
# 0  http://allthingsd.com/20131216/viggle-tries-to...
# 1  http://techcrunch.com/2012/11/28/all-in-the-fa...
# 2  http://techcrunch.com/2012/07/12/betaworks-acq...
# 3  http://techcrunch.com/2011/01/31/exclusive-kit...
# 4  http://www.masshightech.com/stories/2011/04/11...
# 5  http://techcrunch.com/2013/03/13/younow-buys-b...
# 6  http://techcrunch.com/2011/04/27/yahoo-sells-d...
# 7  http://allthingsd.com/20120503/discovery-gets-...
# 8  http://techcrunch.com/2012/02/28/vocus-buys-em...
# 9  http://allthingsd.com/20130417/intel-acquires-...
#
#                       acquisition.source_description  \
# 0   Viggle Tries to Bulk Up Its Social TV Busines...
# 1  MyHeritage acquires Geni and $25M to build fam...
# 2               Betaworks Acquires Digg (TechCrunch)
# 3  KIT digital Acquires KickApps, Kewego AND Kyte...
# 4            Jingle Networks bought for up to $62.5M
# 5  Live Social Video Network YouNow Acquires Stre...
# 6          Yahoo Sells Delicious To YouTube Founders
# 7  Discovery Gets a Web Video Arm, Courtesy of Re...
# 8  Vocus Buys Email Marketing Company iContact Fo...
# 9                 Intel Acquires API Manager Mashery
#
#    acquisition.acquired_year  acquisition.acquired_month  \
# 0                       2013                          12
# 1                       2012                          11
# 2                       2012                           7
# 3                       2011                           1
# 4                       2011                           4
# 5                       2013                           3
# 6                       2011                           4
# 7                       2012                           5
# 8                       2012                           2
# 9                       2013                           4
#
#    acquisition.acquired_day acquisition.acquiring_company.name  \
# 0                        16                             Viggle
# 1                        28                         MyHeritage
# 2                        12                          betaworks
# 3                        31                        KIT digital
# 4                        11                            Marchex
# 5                        13                             YouNow
# 6                        27                       AVOS Systems
# 7                         3           Discovery Communications
# 8                        28                              Vocus
# 9                        17                              Intel
#
#   acquisition.acquiring_company.permalink
# 0                                  viggle
# 1                              myheritage
# 2                               betaworks
# 3                             kit-digital
# 4                                 marchex
# 5                                  younow
# 6                                    avos
# 7                 discoverycommunications
# 8                                   vocus
# 9                                   intel

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
qsearch={"$and":[{"$where" : "this.deadpooled_year > this.founded_year+3" },{"founded_year":{"$ne":None}}]
        }           
rest=list(db.companies.find(qsearch,  {"name":1,
                                       "founded_year" :1,
                                       "deadpooled_year": 1 ,
                                       "_id":0 }).limit(10))
json_normalize(rest) # limit 10 para que no moleste..
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   import sys
#         name  founded_year  deadpooled_year
# 0   Babelgum          2007             2013
# 1      Thoof          2006             2013
# 2     Wesabe          2005             2010
# 3    Stickam          2006             2013
# 4   AllPeers          2004             2008
# 5        EQO          2006             2012
# 6   AllofMP3          2000             2007
# 7  SellABand          2006             2010
# 8       Zlio          2005             2011
# 9      Jaiku          2006             2012
